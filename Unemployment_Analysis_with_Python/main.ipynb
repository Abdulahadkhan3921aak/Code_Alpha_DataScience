# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Unemployment in India.csv")

# %%
df.shape
# Out:
# (768, 7)

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (740, 7)

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
print(df.columns.tolist())

df.columns = df.columns.str.strip()

df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
# Out:
# ['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)', 'Area']

# %%
# collect the date range
start_date = df['Date'].min()
end_date = df['Date'].max()
print(f"Date range: {start_date} to {end_date}")
# Out:
# Date range: 2019-05-31 00:00:00 to 2020-06-30 00:00:00

# %%
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#                     Region Frequency  Estimated Unemployment Rate (%)  \
# Date
# 2019-05-31  Andhra Pradesh   Monthly                             3.65
# 2019-05-31       Telangana   Monthly                             2.23
# 2019-05-31      Tamil Nadu   Monthly                             0.97
# 2019-05-31       Rajasthan   Monthly                             4.03
# 2019-05-31          Punjab   Monthly                             9.17
#
#             Estimated Employed  Estimated Labour Participation Rate (%)   Area
# Date
# 2019-05-31          11999139.0                                    43.24  Rural
# 2019-05-31          11053353.0                                    61.74  Rural
# 2019-05-31          15844698.0                                    49.44  Rural
# 2019-05-31          15226005.0                                    38.52  Rural
# 2019-05-31           6088547.0                                    44.79  Rural

# %%
# collect the Regions in the region column
regions = df['Region'].unique()
print(f"Regions: {regions}")
# Out:
# Regions: ['Andhra Pradesh' 'Telangana' 'Tamil Nadu' 'Rajasthan' 'Punjab'
#  'Puducherry' 'Odisha' 'Meghalaya' 'Maharashtra' 'Madhya Pradesh' 'Kerala'
#  'Tripura' 'Karnataka' 'Jharkhand' 'Jammu & Kashmir' 'Uttar Pradesh'
#  'Himachal Pradesh' 'Haryana' 'Uttarakhand' 'Gujarat' 'Goa' 'Delhi'
#  'Chhattisgarh' 'Chandigarh' 'Bihar' 'Assam' 'West Bengal' 'Sikkim']

# %%
Urbandf = df[df['Area'] == 'Urban']
Ruraldf = df[df['Area'] == 'Rural']

# %%
for region in regions:
    plt.figure(figsize=(12, 6))
    plt.title(f"Unemployment Rate in {region} (Urban)")
    plt.axvline(pd.to_datetime('2020-03-01'), color='r', linestyle='--', label='COVID-19 Start')
    sns.lineplot(data=Urbandf[Urbandf['Region'] == region],
                 x='Date', y='Estimated Unemployment Rate (%)', marker='o')
    plt.xticks(rotation=45)
    plt.xlabel('Date')
    plt.ylabel('Unemployment Rate (%)')
    plt.tight_layout()
    plt.grid()
    plt.show()

# %%
for region in regions:
    plt.figure(figsize=(12, 6))
    plt.title(f"Unemployment Rate in {region} (Rural)")
    plt.axvline(pd.to_datetime('2020-03-01'), color='r', linestyle='--', label='COVID-19 Start')
    sns.lineplot(data=Ruraldf[Ruraldf['Region'] == region],
                 x='Date', y='Estimated Unemployment Rate (%)', marker='o')
    plt.xticks(rotation=45)
    plt.xlabel('Date')
    plt.ylabel('Unemployment Rate (%)')
    plt.tight_layout()
    plt.grid()
    plt.show()
